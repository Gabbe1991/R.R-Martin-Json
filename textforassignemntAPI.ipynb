# %%
import pandas as pd
import requests

# %%
url = "https://openlibrary.org/search.json?q=author:George+R.R.+Martin"

# %%
response = requests.get(url)

# %%
data = response.json()

# %%
#df = pd.json_normalize(data)

# %%
df = pd.DataFrame(data)
df
# Out:
#     numFound  start  numFoundExact  \
# 0         99      0           True
# 1         99      0           True
# 2         99      0           True
# 3         99      0           True
# 4         99      0           True
# ..       ...    ...            ...
# 94        99      0           True
# 95        99      0           True
# 96        99      0           True
# 97        99      0           True
# 98        99      0           True
#
#                                                  docs  num_found  \
# 0   {'author_key': ['OL6787990A'], 'author_name': ...         99
# 1   {'author_key': ['OL6818105A'], 'author_name': ...         99
# 2   {'author_alternative_name': ['Denton B', 'Meli...         99
# 3   {'author_key': ['OL6787990A', 'OL13585934A', '...         99
# 4   {'author_key': ['OL6787990A', 'OL8312223A', 'O...         99
# ..                                                ...        ...
# 94  {'author_alternative_name': ['Cory Doctorow (a...         99
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   numFound       99 non-null     int64
#  1   start          99 non-null     int64
#  2   numFoundExact  99 non-null     bool
#  3   docs           99 non-null     object
#  4   num_found      99 non-null     int64
#  5   q              99 non-null     object
#  6   offset         0 non-null      object
# dtypes: bool(1), int64(3), object(3)
# memory usage: 4.9+ KB
